# %%
df = spark.read.csv(
    "/Volumes/dev_digital_engineering_services/default/databricksmlopspipeline/water_potability.csv",
    header=True,
    inferSchema=True
)

display(df)

# %%
df.printSchema()
df.describe().show()

# %%
from pyspark.sql.functions import col, count

df.select([count(col(c)).alias(c) for c in df.columns]).show()

# %%
df = df.fillna(0)
df = df.dropDuplicates()

# %%
df.write.mode("overwrite").saveAsTable("default.water_potability")
